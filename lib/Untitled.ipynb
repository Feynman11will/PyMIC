# %%
import json
import math
import random
import numpy as np


import matplotlib.pyplot as plt

from PIL import Image
import cv2
np.set_printoptions(threshold=1e6)
import os
import matplotlib.image as mpimg

# %%
paPath = '/data1/wanglonglong/01workspace/PyMIC/examples/lymph/model/result'

# %%
def getNpyList(npyPaths):
    if os.path.isfile(npyPaths):
        npyPaths = os.path.dirname(npyPaths)
    npyPathsList = os.listdir(npyPaths)
    fulllNpyNameList = [os.path.join(npyPaths,npyPath) for npyPath in npyPathsList]
    return fulllNpyNameList

# %%
listFile = getNpyList(paPath)

# %%
listFile = [filename for filename in listFile if not os.path.isfile(filename)]

# %%
listFile
# Out:
# ['/data1/wanglonglong/01workspace/PyMIC/examples/lymph/model/result/0773765',
#  '/data1/wanglonglong/01workspace/PyMIC/examples/lymph/model/result/0773695',
#  '/data1/wanglonglong/01workspace/PyMIC/examples/lymph/model/result/0773709',
#  '/data1/wanglonglong/01workspace/PyMIC/examples/lymph/model/result/0773751',
#  '/data1/wanglonglong/01workspace/PyMIC/examples/lymph/model/result/0773619',
#  '/data1/wanglonglong/01workspace/PyMIC/examples/lymph/model/result/0773779',
#  '/data1/wanglonglong/01workspace/PyMIC/examples/lymph/model/result/0773767',
#  '/data1/wanglonglong/01workspace/PyMIC/examples/lymph/model/result/0773615',
#  '/data1/wanglonglong/01workspace/PyMIC/examples/lymph/model/result/0773691',
#  '/data1/wanglonglong/01workspace/PyMIC/examples/lymph/model/result/0773716',
#  '/data1/wanglonglong/01workspace/PyMIC/examples/lymph/model/result/0773610',
#  '/data1/wanglonglong/01workspace/PyMIC/examples/lymph/model/result/0773642',
# ...

# %%
name1 = getNpyList(listFile[0])

# %%
print(name1)
# Out:
# ['/data1/wanglonglong/01workspace/PyMIC/examples/lymph/model/result/0773765/1.2.840.113619.2.334.3.168431628.262.1525995644.140']

# %%
imgName = '/data1/wanglonglong/01workspace/PyMIC/examples/lymph/model/result/0773598/1.2.840.113619.2.334.3.168431628.257.1553813081.326/1.2.840.113619.2.334.3.168431628.257.1553813081.331.3/image_8.png'

# %%
imgName
# Out:
# '/data1/wanglonglong/01workspace/PyMIC/examples/lymph/model/result/0773598/1.2.840.113619.2.334.3.168431628.257.1553813081.326/1.2.840.113619.2.334.3.168431628.257.1553813081.331.3/image_8.png'

# %%
img =  mpimg.imread(imgName)
plt.imshow(img,cmap = 'gray')

# %%
orgImgPath = '/data1/wanglonglong/DataSet/DeepwiseLabelLymphNodes/label/image/0773598/1.2.840.113619.2.334.3.168431628.257.1553813081.326/1.2.840.113619.2.334.3.168431628.257.1553813081.331.3/image_8.npy'

# %%
orgImgPath
# Out:
# '/data1/wanglonglong/DataSet/DeepwiseLabelLymphNodes/label/image/0773598/1.2.840.113619.2.334.3.168431628.257.1553813081.326/1.2.840.113619.2.334.3.168431628.257.1553813081.331.3/image_8.npy'

# %%
orgImg = np.load(orgImgPath)

# %%
plt.imshow(orgImg,cmap = 'gray')

# %%
orgImgPath = '/data1/wanglonglong/DataSet/DeepwiseLabelLymphNodes/label/mask/0773598/1.2.840.113619.2.334.3.168431628.257.1553813081.326/1.2.840.113619.2.334.3.168431628.257.1553813081.331.3/mask_8.npy'

# %%
orgImg = np.load(orgImgPath)
plt.imshow(orgImg,cmap = 'gray')
