# %%
import os 
import sys
from makeLabel import getStatics

# %%
idList1 = ['0773601', '0773713', '0773615', '0773698', '0773665']
idList2 = ['0773669', '0773667', '0773672', '0773679', '0773760', '0773705', '0773652', '0773737', '0773730', '0773773', '0773686']

# %%
idLIst = idList1+idList2

# %%
idLIst
# Out:
# ['0773601',
#  '0773713',
#  '0773615',
#  '0773698',
#  '0773665',
#  '0773669',
#  '0773667',
#  '0773672',
#  '0773679',
#  '0773760',
#  '0773705',
#  '0773652',
#  '0773737',
#  '0773730',
#  '0773773',
#  '0773686']

# %%
pathTask_10493_0='/data1/wanglonglong/DataSet/DeepwiseLabelLymphNodes/task_10493_0.json'
parentPath ='/data1/wanglonglong/DataSet/DeepwiseLabelLymphNodes/auto_rebuild'
outputParentPath = '/data1/wanglonglong/DataSet/DeepwiseLabelLymphNodes'

# %%
getStatics(parentPath, pathTask_10493_0, outputParentPath,idLIst)
# Out:
# 16
# /home/wanglonglong/.local/lib/python3.6/site-packages/pydicom/filereader.py:313: UserWarning: Expected explicit VR, but found implicit VR - using implicit VR for reading
#   warnings.warn(message, UserWarning)
# (662, 512, 512)
# (662, 512, 512)
# /data1/wanglonglong/DataSet/DeepwiseLabelLymphNodes/label/image/0773601/1.2.840.113619.186.808613390227.20190801100811611.151/1.3.12.2.1107.5.1.4.75542.30000019073123545266100028588/image_97
# /data1/wanglonglong/DataSet/DeepwiseLabelLymphNodes/label/mask/0773601/1.2.840.113619.186.808613390227.20190801100811611.151/1.3.12.2.1107.5.1.4.75542.30000019073123545266100028588/mask_97
# --------------------------------------------------
# /data1/wanglonglong/DataSet/DeepwiseLabelLymphNodes/label/image/0773601/1.2.840.113619.186.808613390227.20190801100811611.151/1.3.12.2.1107.5.1.4.75542.30000019073123545266100028588/image_98
# ...
